# %% [markdown]
# # Inferential Statistics

# %% [raw]
# Inferential Statistics makes inferences and predictions about the population based on a sample of data taken from the population. It generalizes a large dataset and applies probabilities to draw a conclusion.

# %% [raw]
# Inferential Statistics is mainly related to and associated with hypothesis testing whose main target is to reject the null hypothesis.

# %% [raw]
# Hypothesis testing is a type of inferential procedure that takes the help of sample data to evaluate and assess the credibility of a hypothesis about a population.

# %%
# Types of Inferential Statistics

# %% [raw]
# Various types of inferential statistics are used widely nowadays and are very easy to interpret. These are given below:
#
# -> One sample test of difference/One sample hypothesis test
# -> Confidence Interval
# -> Contingency Tables and Chi-Square Statistic
# -> T-test or Anova
# -> Pearson Correlation
# -> Bivariate Regression
# -> Multi-variate Regression

# %% [markdown]
# ## One Sample t-test

# %% [raw]
# Z-test are commonly done when the population standard deviation is known.
# t-test are commonly done when the population standard deviation is unknown.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Alpha = 0.05

# %% [raw]
# Steps:
#     1) Define Null and Alternative Hypothesis
#     2) State Alpha
#     3) Calculate Degree of Freedom
#     4) State Decision Rule
#     5) Calculate Test Statistic
#     6) State Results
#     7) State Conclusions

# %% [markdown]
# ## 1) Define Null and Alternative Hypothesis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) State Alpha

# %% [raw]
# Alpha = 0.05

# %% [markdown]
# ## 3) Calculate Degree of Freedom

# %% [raw]
# n - 1

# %% [raw]
# Always N = population and n = sample

# %% [raw]
# n - 1 => 30 - 1 = 29

# %% [markdown]
# ## 4) State Decision Rule

# %% [markdown]
# ![Screenshot%202024-01-05%20at%2012.53.46%E2%80%AFPM.png](attachment:Screenshot%202024-01-05%20at%2012.53.46%E2%80%AFPM.png)

# %% [raw]
# We want to find the middle 95% of where we would expect to the mean to be it's outside of that in this two tailed test we are going to conclude that the mean we have is strange and likely is different from the population we are comparing it to.

# %%
# T-table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Our Alpha is 0.05 and Degree of Freedom is 29

# %% [raw]
# Critical_value = 2.045

# %% [markdown]
# ![Screenshot%202024-01-05%20at%201.07.38%E2%80%AFPM.png](attachment:Screenshot%202024-01-05%20at%201.07.38%E2%80%AFPM.png)

# %%
# which means expected values are different and it is not same

# %% [markdown]
# ## 5) Calculate Test Static

# %% [markdown]
# ![Screenshot%202024-01-05%20at%201.09.40%E2%80%AFPM.png](attachment:Screenshot%202024-01-05%20at%201.09.40%E2%80%AFPM.png)

# %% [markdown]
# ## 6) State Results

# %% [markdown]
# ![Screenshot%202024-01-05%20at%201.10.03%E2%80%AFPM.png](attachment:Screenshot%202024-01-05%20at%201.10.03%E2%80%AFPM.png)

# %% [markdown]
# ## 7) State Conclusion

# %% [raw]
# Medication significantly affected intelligence, t = 10.96, p<0.05
