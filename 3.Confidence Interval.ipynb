# %% [markdown]
# # Confidence Interval

# %% [raw]
# CI is the range of estimates for an unknown parameter. CI is computed at designated confidence level, 95% confidence level is most common.

# %% [raw]
# CI = X' + (lambda 2) * (Std / Sqrt(Sample size)

# %% [markdown]
# ![Screenshot%202023-12-04%20at%209.05.36%E2%80%AFPM.png](attachment:Screenshot%202023-12-04%20at%209.05.36%E2%80%AFPM.png)

# %% [markdown]
# # Estimate

# %% [raw]
# Estimate is specified observed numerical value used to estimate an unknown population parameter
#         1) Point estimate -> single numerical value
#         2) Interval estimate -> Range of values

# %% [raw]
# A researcher took a sample of 30 students’ test scores with an average score of 85 and a standard deviation of 5. What is the 95% confidence interval for the test scores?

# %% [raw]
# What is point estimate?
#    Point Estimate is important inorder to find out the CI
#
#
# usually in most of the experiment
# its very difficult to find the population mean ,
# because the population size is huge.
#
# with respect to that we may be able to find the sample mean
# if you have some sample values wrt to population we may able
# to find the sample mean. which can be repsented as x'
#
# with the help of this x' we may try to estimate the mean of the population
#
# in this particular scenario x' is nothing but the Point Estimate
#
# Based on the central limit theorem
#
# if you take multiple sample from tha population and creating sample mean it can be
# approximately equal to the population mean this is excatly POINT ESTIMATE

# %% [raw]
# CI Says that by considering this particular sample mean with some confidence interval
# 95% i will be find out some range of population mean from what limit to what limit ?
#
#                   95%
#
#        |                    |
#
#    lowerlimit           higher limit
#
# this particular range may be with 95% CI
#
#
# find out the average size of sharks in the sea ?

# %% [raw]
# my population (std_dev)=100
#
# sample (n)=30
#
# sample mean (x')=500
#
# CI=PointEstimate +  Margin Error
#                  -

# %%
import numpy as np

# %%
import pandas as pd

# %% [raw]
# CI for single population mean.
#
#     A sample of n=50 males showed a mean average daily intake of food equal to 756 grams with standard deviation of 35 gram. Find the 95% confidence interval. For the population mean.

# %% [raw]
# x' + z * (Std / sqrt(n))

# %% [raw]
#         x' -> Point estimate
# z*(Std/sqrt(n)) -> Margin error

# %%
x_bar = 756

# %%
n = 50

# %%
std = 35

# %%
z = 1.96

# %% [raw]
# which means 95%

# %%
sqrt = np.sqrt(50)

# %%
sqrt
# Out:
# 7.0710678118654755

# %%
std / sqrt
# Out:
# 4.949747468305833

# %%
Margin_error = 1.96 * 4.949747468305833

# %%
Margin_error
# Out:
# 9.701505037879432

# %%
756 + Margin_error
# Out:
# 765.7015050378794

# %%
756 - Margin_error
# Out:
# 746.2984949621206

# %%
upper_confidence_interval = 765.7015050378794

# %%
lower_confidence_interval = 746.2984949621206

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Z-Score

# %% [raw]
# (1 + CI) / 2

# %%
(1 + 0.95) / 2
# Out:
# 0.975

# %%
# Z-Table

# %% [raw]
# Now checking 0.975 in the z-table

# %%
1.9 + 0.06 # (row_value + column_value)
# Out:
# 1.96

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Whenever the population standard deviation is given, we have to use Z-test

# %% [raw]
# Sigficance / 2 => 5% => 0.05

# %%
95 + 5 # (0.95 + 0.05 => 1.00)
# Out:
# 100

# %%
0.95 + 0.05
# Out:
# 1.0

# %% [markdown]
# ![Screenshot%202023-12-04%20at%209.57.38%E2%80%AFPM.png](attachment:Screenshot%202023-12-04%20at%209.57.38%E2%80%AFPM.png)

# %% [raw]
# 2.5% => 0.025

# %%
1 - 0.025
# Out:
# 0.975
